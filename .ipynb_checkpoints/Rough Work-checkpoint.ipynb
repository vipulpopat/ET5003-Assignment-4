# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pymc3 as pm
from scipy.stats import multivariate_normal
from statsmodels.tsa.seasonal import seasonal_decompose
import GPy as GPy

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Data
# To being we load the data and do some preliminary inspection in an attempt to understand the problem space, the data presented and the model that it describes.

# %%
data = pd.read_csv('./data/train.csv')
data.head(10)
# Out:
#     Id         0         1         2         3         4         5         6  \
# 0  120  0.147298 -0.142030  0.091737 -0.151707  0.060124  0.186191 -0.021298
# 1  121  0.115710  0.105061  0.038446  0.166711 -0.113913  0.004528 -0.006954
# 2  122 -0.548826 -0.466551 -0.650890 -0.553450 -0.449101 -0.496902 -0.464860
# 3  123  0.192618  0.291155 -0.042980  0.146483  0.015390  0.019394 -0.005577
# 4  124  0.075706  0.069045 -0.019818  0.068801 -0.226501  0.011658  0.087905
# 5  125  1.081769  0.986722  1.067524  1.140523  0.975286  1.074729  0.871820
# 6  126  0.212677  0.271821  0.052499  0.353935  0.177247  0.165208  0.077037
# 7  127 -1.044003 -0.994305 -0.885585 -0.678902 -0.717464 -0.513387 -0.501884
# 8  128  0.984083  0.938459  0.956299  0.922269  1.078399  1.107597  0.983515
# 9  129 -0.056781  0.053274  0.033048  0.010449  0.101132 -0.055987 -0.045404
#
#           7         8  ...        91        92        93        94        95  \
# 0 -0.025636  0.061044  ... -0.218118  0.011316  0.079464 -0.010833 -0.053485
# 1 -0.140054  0.154231  ...  0.021526  0.069009 -0.060343  0.094007  0.049558
# 2 -0.394458 -0.271801  ...  0.057272  0.088062 -0.069730  0.168498  0.109672
# 3 -0.048682  0.025772  ...  0.140831  0.257332  0.262786  0.351659  0.213291
# 4 -0.080787 -0.080369  ...  0.434803  0.322841  0.297772  0.461421  0.406143
# 5  1.140957  1.276274  ...  2.098946  1.882913  1.979897  1.852567  2.043995
# 6  0.054077  0.001218  ...  0.880501  0.894316  0.776692  0.910526  1.145064
# 7 -0.647595 -0.336069  ...  0.607999  0.508485  0.442513  0.644257  0.838618
# 8  1.222726  1.049279  ...  1.937170  1.951902  2.069157  2.075734  1.953834
# 9  0.012941 -0.047868  ...  0.231157  0.182868  0.240331  0.156288  0.218797
#
#          96        97        98        99  Category
# 0  0.046450 -0.008333  0.168574  0.123273         0
# 1  0.112370  0.020398  0.039687  0.217384         0
# 2  0.202808 -0.019942  0.058902  0.053936         0
# 3  0.251077  0.190920  0.251743  0.337730         1
# 4  0.562082  0.554588  0.471489  0.384229         1
# 5  2.059601  2.219500  2.038103  2.072409         1
# 6  1.302965  1.182394  1.286594  1.184424         1
# 7  0.936488  0.929766  0.965134  1.024578         1
# 8  1.922141  1.913410  1.965790  1.956595         0
# 9  0.042883  0.127180  0.130278  0.162561         0
#
# [10 rows x 102 columns]

# %% [markdown]
# # Data Analysis - Seasonality
# The dataset provided deals with sales data over a period of time. As such we will first inspect that data to see if what we are seeing is the sales trend alone or if it includes a seasonal component. This is important to ensure our predictions are based on the trend and not seasonality.

# %%
country_id = 15

ax = data.iloc[country_id,1:101].plot(figsize = (15,6), title=f"Sales Data for Country {country_id}", legend = False)
ax.set(xlabel="Time")
plt.show()

# %% [markdown]
# The above plot shows the sales data, unaltered for a single country. We can observe an upward trend over time. The jaggedness of the data may indicate a periodic component. The following sections aim to discover if that is the case.

# %%
sales_all = data.iloc[:,1:101]
sales_all.rolling(2).mean().plot(figsize = (15,6), title="Sales Data", linewidth=2, fontsize=18, legend = False)
plt.xlabel('Time', fontsize=12);
plt.show()

# %% [markdown]
# Tried to find out first, if there is a periodic cycle in the data and if so what is it's frequency.
# * 365 - Days
#  * Resulted in no data meaning not a daily period
# * 52 - Weeks
#  * Resulted in some results but not over the entire series
# * 12 - Months
#  * Resulted in something started to form here but still not complete
# * 4 - Seasons (Summer, Autumn, Winter, Spring)
#  * Got a much longer trend forming across the data indicating seasonality is present
# * 2 - Seasons (Summer, Winter)
#  * Got a similar view, difficult to tell between full seasons or short seasons

# %%
sales_all.diff().plot(figsize=(20,10), title="Sales Data", linewidth=2, fontsize=20, legend=False)
plt.xlabel('Time', fontsize=20);

# %% [markdown]
# By removing the trend from the data we can see a very clear pattern of highs and lows. This would lead us to believe that there is in fact periodicity in the data. Due to the pattern extreme high followed by extreme low we've deduced that the seasonality is dual in nature.

# %%
pd.plotting.autocorrelation_plot(sales_all)

# %% [markdown]
# Auto correlation plot look for randomness in the data. This is done by computing autocorrelations for data values at varying time lags. The dotted lines indicate 95% confidence.
#
# TODO vrify that since the plot does not exceed the 95% threshold the values for sales figures are not correlated. Or put another way, the sales figures collected on one day have no dependence on those collected on the previous day.

# %% [markdown]
# # Stationary Time Series
# Now that we have concluded that a seasonal periodic pattern exists, and what we believe the frequency to be, in the data we want to remove it. In other words, we want our time series to be stationary.
#
# A stationary time series is...... TODO defnition
#
# We'll take another looks at the data, this time for a single country.

# %%
sales = data.iloc[country_id,1:101]
sales.rolling(2).mean().plot(figsize = (12,2), title=f"Sales Trend for Country {country_id}", linewidth=2, legend = False)
plt.xlabel('Time');
plt.show()

# %%
sales.diff().plot(figsize=(12,2), title=f"Sales Diff for Country {country_id}", linewidth=2, legend=False)
plt.xlabel('Time');

# %% [markdown]
# Here we are looking at the same plots as above, except focusing on a single country. These are shown to justify our choice below to use statsmodels seasonal_decompose function. In comparison we can see that the trend and residual sections line up with our Sales Trend and Sales Diff plots.
#
# From here on we will use statsmodels functions to identify the trends in the data.

# %%
decomp_single = seasonal_decompose(data.iloc[country_id,1:101].T, model='additive', freq=2, extrapolate_trend='freq')
decomp_single.plot()
plt.show()

# %% [markdown]
# From this plot we can see a couple of interesting elements:
# * Observed - This shows us the values observed for this country over time, unaltered
# * Trend - We can conclude from above that this view is also generated using a rolling mean
# * Seasonal - The interesting point here is the very small range that the seasonality covers, only +- 0.0025
# * Residual - Follows a similar pattern to the difference plot which we used to see a periodic pattern in the data

# %% [markdown]
# # Modeling the Trend
# Now that we have methods for identifying a trend in the data we will attempt to model it. Firstly we will continue with the same country shown above.

# %%
X = np.linspace(0,1,100)[:, None]
Y = decomp_single.trend[:, None]
plt.figure(figsize=(12, 2))
plt.plot(X,Y)

# %% [markdown]
# The trend data shown over a standardized [0,1] space

# %%
def model_kernel():
    '''
    Helper function that will allow the same kernel to be used elsewhere
    '''
    
    ker1 = GPy.kern.Linear(1)
    ker2 = GPy.kern.ExpQuad(1)
    
    kernel = ker1+ker2
    return kernel

# %% [markdown]
# This method served as a bit of a focal point for efforts. The goal here was to model the data by way of one or more covariance functions (kernels). Each kernel has different properties that fit to different patterns.
#
# TODO: This section is important. Try to bring it together from others notebooks.

# %%
# Create our model and optomize the parameters
kernel = model_kernel()
s_model = GPy.models.GPRegression(X,Y,kernel=kernel)
s_model.optimize_restarts(20, robust=True, verbose=False, parallel=True, num_processes=12)

# Plot the results
fig = s_model.plot(figsize=(20,5))
display(s_model)
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -141.59814901252656<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 4<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.linear.variances   </td><td class=tg-right>   3.1733945068227842</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ExpQuad.variance   </td><td class=tg-right>   0.5187528162634091</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ExpQuad.lengthscale</td><td class=tg-right>  0.24879245318444781</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.0021314707681186957</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# ## GPy Model Output
# Here we can see the output from our generated model. The points are the observed data that we passed in, an evenly spaces series of values between 0 & 1. The line is the mean value of the data and the shaded area is our confidence level.
#
# An interesting aspect is how the area widens the further away we get from the observed points.
#
# TODO: More to fill in as to explaination

# %% [markdown]
# # Training
# Using a number of single examples we attempted to model the data. With that in place we started training against the test set, verifying our results against the labels provided to us.

# %%
def run_model(x_in, y_in):
    '''
    Will run a model using the kernel defined earlier. Sampling will then allow us to 
    calculate the posterior probability that the sales trend is increasing for the given country
    '''

    kernel = model_kernel()
    model = GPy.models.GPRegression(x_in,y_in,kernel=kernel)
    model.optimize_restarts(20, robust=True, verbose=False, parallel=True, num_processes=12)
    
    # Generate a new set of X values, evenly spaced between 0,1
    x_new = X = np.linspace(0,1,100).reshape(-1,1)
    
    # Get the posterior distribution and sample
    f_pred, sigm_pred = model.predict_noiseless(x_new, full_cov=True, kern=kernel)
    Z = np.random.multivariate_normal(f_pred.T[0], sigm_pred, 1000).T
    
    posterior_der_pos = (np.diff(np.mean(Z.T,axis=0), 1)>0).sum()/len(np.mean(Z.T,axis=0))
    
    if posterior_der_pos>0.95:
        return 1
    else:
        return 0

# %% [markdown]
# # Training Data
# Before applying our model to unseen data, we train and validate against known training data with set labels

# %%
num_rows = 75
actual = data.iloc[0:num_rows, -1]
predicted = []
x_d = np.linspace(0,1,100)[:, None]
for x in range(num_rows):
    print(f'Iteration: {x+1} of {num_rows}')
    decomp = seasonal_decompose(data.iloc[x,1:101].T, model='additive', freq=2, extrapolate_trend='freq')
    y_d = decomp.trend.values[:, None]
    decision = run_model(x_d,y_d)
    predicted.append(decision)
# Out:
# Iteration: 1 of 75
# Iteration: 2 of 75
# Iteration: 3 of 75
# Iteration: 4 of 75
# Iteration: 5 of 75
# Iteration: 6 of 75
# Iteration: 7 of 75
# Iteration: 8 of 75
# Iteration: 9 of 75
# Iteration: 10 of 75
# Iteration: 11 of 75
# Iteration: 12 of 75
# Iteration: 13 of 75
# Iteration: 14 of 75
# Iteration: 15 of 75
# Iteration: 16 of 75
# Iteration: 17 of 75
# Iteration: 18 of 75
# Iteration: 19 of 75
# Iteration: 20 of 75
# Iteration: 21 of 75
# Iteration: 22 of 75
# Iteration: 23 of 75
# Iteration: 24 of 75
# Iteration: 25 of 75
# Iteration: 26 of 75
# Iteration: 27 of 75
# Iteration: 28 of 75
# Iteration: 29 of 75
# Iteration: 30 of 75
# Iteration: 31 of 75
# Iteration: 32 of 75
# Iteration: 33 of 75
# Iteration: 34 of 75
# Iteration: 35 of 75
# Iteration: 36 of 75
# Iteration: 37 of 75
# Iteration: 38 of 75
# Iteration: 39 of 75
# Iteration: 40 of 75
# Iteration: 41 of 75
# Iteration: 42 of 75
# Iteration: 43 of 75
# Iteration: 44 of 75
# Iteration: 45 of 75
# Iteration: 46 of 75
# Iteration: 47 of 75
# Iteration: 48 of 75
# Iteration: 49 of 75
# Iteration: 50 of 75
# Iteration: 51 of 75
# Iteration: 52 of 75
# Iteration: 53 of 75
# Iteration: 54 of 75
# Iteration: 55 of 75
# Iteration: 56 of 75
# Iteration: 57 of 75
# Iteration: 58 of 75
# Iteration: 59 of 75
# Iteration: 60 of 75
# Iteration: 61 of 75
# Iteration: 62 of 75
# Iteration: 63 of 75
# Iteration: 64 of 75
# Iteration: 65 of 75
# Iteration: 66 of 75
# Iteration: 67 of 75
# Iteration: 68 of 75
# Iteration: 69 of 75
# Iteration: 70 of 75
# Iteration: 71 of 75
# Iteration: 72 of 75
# Iteration: 73 of 75
# Iteration: 74 of 75
# Iteration: 75 of 75

# %% [markdown]
# # Results
# Training complete we can now review our accuracy to determine how well our model performed

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

results = confusion_matrix(actual, predicted) 
print(results)
print(f'Accuracy Score: {accuracy_score(actual, predicted)}')
print('The Report:')
print(classification_report(actual, predicted))
# Out:
# [[45  4]
#  [18  8]]
# Accuracy Score: 0.7066666666666667
# The Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80        49
#            1       0.67      0.31      0.42        26
#
#     accuracy                           0.71        75
#    macro avg       0.69      0.61      0.61        75
# weighted avg       0.70      0.71      0.67        75

# %% [markdown]
# # Unseen
# Once we are happy with the performance of our model we can use it against the unseen dataset. This is a true measure of how well we have modeled our data.

# %%
allow_test = True
if allow_test:
    test_df = pd.read_csv("./data/test.csv")
    rows = test_df.shape[0]
    x_t = np.linspace(0,1,100)[:, None]
    
    Decision = pd.DataFrame(columns=['Id','Category'])
    for r in range(rows):
        print(f'Iteration: {r+1} of {rows}')
        id_row = test_df.iloc[r,0]
        decomp_t = seasonal_decompose(test_df.iloc[x,1:101].T, model='additive', freq=2, extrapolate_trend='freq')
        y_t = decomp_t.trend.values[:, None]
        decision = run_model(x_t,y_t)
        print(f'Decision is {decision} for Id {id_row}')
        Decision = Decision.append({'Id': int(id_row), 'Category': int(decision)}, ignore_index=True) 

    Decision.to_csv('submission.csv', index=False)
# Out:
# Iteration: 1 of 120
# Decision is 0 for Id 0
# Iteration: 2 of 120
# Decision is 0 for Id 1
# Iteration: 3 of 120
# Decision is 0 for Id 2
# Iteration: 4 of 120
# Decision is 0 for Id 3
# Iteration: 5 of 120
# Decision is 0 for Id 4
# Iteration: 6 of 120
# Decision is 0 for Id 5
# Iteration: 7 of 120
# Decision is 0 for Id 6
# Iteration: 8 of 120
# Decision is 0 for Id 7
# Iteration: 9 of 120
# Decision is 0 for Id 8
# Iteration: 10 of 120
# Decision is 0 for Id 9
# Iteration: 11 of 120
# Decision is 0 for Id 10
# Iteration: 12 of 120
# Decision is 0 for Id 11
# Iteration: 13 of 120
# Decision is 0 for Id 12
# Iteration: 14 of 120
# Decision is 0 for Id 13
# Iteration: 15 of 120
# Decision is 0 for Id 14
# Iteration: 16 of 120
# Decision is 0 for Id 15
# Iteration: 17 of 120
# Decision is 0 for Id 16
# Iteration: 18 of 120
# Decision is 0 for Id 17
# Iteration: 19 of 120
# Decision is 0 for Id 18
# Iteration: 20 of 120
# Decision is 0 for Id 19
# Iteration: 21 of 120
# Decision is 0 for Id 20
# Iteration: 22 of 120
# Decision is 0 for Id 21
# Iteration: 23 of 120
# Decision is 0 for Id 22
# Iteration: 24 of 120
# Decision is 0 for Id 23
# Iteration: 25 of 120
# Decision is 0 for Id 24
# Iteration: 26 of 120
# Decision is 0 for Id 25
# Iteration: 27 of 120
# Decision is 0 for Id 26
# Iteration: 28 of 120
# Decision is 0 for Id 27
# Iteration: 29 of 120
# Decision is 0 for Id 28
# Iteration: 30 of 120
# Decision is 0 for Id 29
# Iteration: 31 of 120
# Decision is 0 for Id 30
# Iteration: 32 of 120
# Decision is 0 for Id 31
# Iteration: 33 of 120
# Decision is 0 for Id 32
# Iteration: 34 of 120
# Decision is 0 for Id 33
# Iteration: 35 of 120
# Decision is 0 for Id 34
# Iteration: 36 of 120
# Decision is 0 for Id 35
# Iteration: 37 of 120
# Decision is 0 for Id 36
# Iteration: 38 of 120
# Decision is 0 for Id 37
# Iteration: 39 of 120
# Decision is 0 for Id 38
# Iteration: 40 of 120
# Decision is 0 for Id 39
# Iteration: 41 of 120
# Decision is 0 for Id 40
# Iteration: 42 of 120
# Decision is 0 for Id 41
# Iteration: 43 of 120
# Decision is 0 for Id 42
# Iteration: 44 of 120
# Decision is 0 for Id 43
# Iteration: 45 of 120
# Decision is 0 for Id 44
# Iteration: 46 of 120
# Decision is 0 for Id 45
# Iteration: 47 of 120
# Decision is 0 for Id 46
# Iteration: 48 of 120
# Decision is 0 for Id 47
# Iteration: 49 of 120
# Decision is 0 for Id 48
# Iteration: 50 of 120
# Decision is 0 for Id 49
# Iteration: 51 of 120
# Decision is 0 for Id 50
# Iteration: 52 of 120
# Decision is 0 for Id 51
# Iteration: 53 of 120
# Decision is 0 for Id 52
# Iteration: 54 of 120
# Decision is 0 for Id 53
# Iteration: 55 of 120
# Decision is 0 for Id 54
# Iteration: 56 of 120
# Decision is 0 for Id 55
# Iteration: 57 of 120
# Decision is 0 for Id 56
# Iteration: 58 of 120
# Decision is 0 for Id 57
# Iteration: 59 of 120
# Decision is 0 for Id 58
# Iteration: 60 of 120
# Decision is 0 for Id 59
# Iteration: 61 of 120
# Decision is 0 for Id 60
# Iteration: 62 of 120
# Decision is 0 for Id 61
# Iteration: 63 of 120
# Decision is 0 for Id 62
# Iteration: 64 of 120
# Decision is 0 for Id 63
# Iteration: 65 of 120
# Decision is 0 for Id 64
# Iteration: 66 of 120
# Decision is 0 for Id 65
# Iteration: 67 of 120
# Decision is 0 for Id 66
# Iteration: 68 of 120
# Decision is 0 for Id 67
# Iteration: 69 of 120
# Decision is 0 for Id 68
# Iteration: 70 of 120
# Decision is 0 for Id 69
# Iteration: 71 of 120
# Decision is 0 for Id 70
# Iteration: 72 of 120
# Decision is 0 for Id 71
# Iteration: 73 of 120
# Decision is 0 for Id 72
# Iteration: 74 of 120
# Decision is 0 for Id 73
# Iteration: 75 of 120
# Decision is 0 for Id 74
# Iteration: 76 of 120
# Decision is 0 for Id 75
# Iteration: 77 of 120
# Decision is 0 for Id 76
# Iteration: 78 of 120
# Decision is 0 for Id 77
# Iteration: 79 of 120
# Decision is 0 for Id 78
# Iteration: 80 of 120
# Decision is 0 for Id 79
# Iteration: 81 of 120
# Decision is 0 for Id 80
# Iteration: 82 of 120
# Decision is 0 for Id 81
# Iteration: 83 of 120
# Decision is 0 for Id 82
# Iteration: 84 of 120
# Decision is 0 for Id 83
# Iteration: 85 of 120
# Decision is 0 for Id 84
# Iteration: 86 of 120
# Decision is 0 for Id 85
# Iteration: 87 of 120
# Decision is 0 for Id 86
# Iteration: 88 of 120
# Decision is 0 for Id 87
# Iteration: 89 of 120
# Decision is 0 for Id 88
# Iteration: 90 of 120
# Decision is 0 for Id 89
# Iteration: 91 of 120
# Decision is 0 for Id 90
# Iteration: 92 of 120
# Decision is 0 for Id 91
# Iteration: 93 of 120
# Decision is 0 for Id 92
# Iteration: 94 of 120
# Decision is 0 for Id 93
# Iteration: 95 of 120
# Decision is 0 for Id 94
# Iteration: 96 of 120
# Decision is 0 for Id 95
# Iteration: 97 of 120
# Decision is 0 for Id 96
# Iteration: 98 of 120
# Decision is 0 for Id 97
# Iteration: 99 of 120
# Decision is 0 for Id 98
# Iteration: 100 of 120
# Decision is 0 for Id 99
# Iteration: 101 of 120
# Decision is 0 for Id 100
# Iteration: 102 of 120
# Decision is 0 for Id 101
# Iteration: 103 of 120
# Decision is 0 for Id 102
# Iteration: 104 of 120
# Decision is 0 for Id 103
# Iteration: 105 of 120
# Decision is 0 for Id 104
# Iteration: 106 of 120
# Decision is 0 for Id 105
# Iteration: 107 of 120
# Decision is 0 for Id 106
# Iteration: 108 of 120
# Decision is 0 for Id 107
# Iteration: 109 of 120
# Decision is 0 for Id 108
# Iteration: 110 of 120
# Decision is 0 for Id 109
# Iteration: 111 of 120
# Decision is 0 for Id 110
# Iteration: 112 of 120
# Decision is 0 for Id 111
# Iteration: 113 of 120
# Decision is 0 for Id 112
# Iteration: 114 of 120
# Decision is 0 for Id 113
# Iteration: 115 of 120
# Decision is 0 for Id 114
# Iteration: 116 of 120
# Decision is 0 for Id 115
# Iteration: 117 of 120
# Decision is 0 for Id 116
# Iteration: 118 of 120
# Decision is 0 for Id 117
# Iteration: 119 of 120
# Decision is 0 for Id 118
# Iteration: 120 of 120
# Decision is 0 for Id 119
